# %% [markdown]
# # Brain Stroke Prediction

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical
import time
import sys

# %%
# Read the CSV file without setting any column as the index
df = pd.read_csv("C:\\Users\\ssrut\\OneDrive\\Desktop\\Sem 5\\CP3 projects\\Iot project\\Data\\brain_stroke.csv")
df.head()
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
# Convert 'ever_married' to binary (0s and 1s)
df['ever_married'] = df['ever_married'].map({'Yes': 1, 'No': 0})

# Convert 'work_type' to binary, treating 'Private' as 1 and all other types as 0
df['work_type'] = df['work_type'].apply(lambda x: 1 if x == 'Private' else 0)

# Convert 'Residence_type' to binary (Urban as 1, Rural as 0)
df['Residence_type'] = df['Residence_type'].map({'Urban': 1, 'Rural': 0})

# Convert 'smoking_status' to binary, treating 'smokes' as 1 and all other types as 0
df['smoking_status'] = df['smoking_status'].apply(lambda x: 1 if x == 'smokes' else 0)

# Convert float columns 'avg_glucose_level' and 'bmi' to integers
df['avg_glucose_level'] = df['avg_glucose_level'].astype(int)
df['bmi'] = df['bmi'].astype(int)

# Display the final DataFrame
print(df.head())
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0    Male  67.0             0              1             1          1
# 1    Male  80.0             0              1             1          1
# 2  Female  49.0             0              0             1          1
# 3  Female  79.0             1              0             1          0
# 4    Male  81.0             0              0             1          1
#
#    Residence_type  avg_glucose_level  bmi  smoking_status  stroke
# 0               1                228   36               0       1
# 1               0                105   32               0       1
# 2               1                171   34               1       1
# 3               0                174   24               0       1
# 4               1                186   29               0       1

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
print("Unique values in 'stroke' column:", df['stroke'].unique())
# Out:
# Unique values in 'stroke' column: [1 0]

# %%
# Get basic statistics for numerical columns
print("\nSummary statistics for numerical columns:")
df.describe()
# Out:
# Summary statistics for numerical columns:
#                age  hypertension  heart_disease  ever_married    work_type  \
# count  4981.000000   4981.000000    4981.000000   4981.000000  4981.000000
# mean     43.419859      0.096165       0.055210      0.658502     0.574182
# std      22.662755      0.294848       0.228412      0.474260     0.494516
# min       0.080000      0.000000       0.000000      0.000000     0.000000
# 25%      25.000000      0.000000       0.000000      0.000000     0.000000
# 50%      45.000000      0.000000       0.000000      1.000000     1.000000
# 75%      61.000000      0.000000       0.000000      1.000000     1.000000
# max      82.000000      1.000000       1.000000      1.000000     1.000000
#
#        Residence_type  avg_glucose_level          bmi  smoking_status  \
# count     4981.000000        4981.000000  4981.000000     4981.000000
# mean         0.508332         105.454126    28.055611        0.155792
# std          0.499981          45.065510     6.782413        0.362694
# min          0.000000          55.000000    14.000000        0.000000
# 25%          0.000000          77.000000    23.000000        0.000000
# 50%          1.000000          91.000000    28.000000        0.000000
# 75%          1.000000         113.000000    32.000000        0.000000
# max          1.000000         271.000000    48.000000        1.000000
#
#             stroke
# count  4981.000000
# mean      0.049789
# std       0.217531
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
# Get the unique values in each column to see if there are categorical data
print("\nUnique values in each column:")
for column in df.columns:
    print(f"{column}: {df[column].nunique()} unique values")
# Out:
# Unique values in each column:
# gender: 2 unique values
# age: 104 unique values
# hypertension: 2 unique values
# heart_disease: 2 unique values
# ever_married: 2 unique values
# work_type: 2 unique values
# Residence_type: 2 unique values
# avg_glucose_level: 207 unique values
# bmi: 35 unique values
# smoking_status: 2 unique values
# stroke: 2 unique values

# %% [markdown]
# ### Encoding

# %%
# Encode categorical columns
label_encoder = LabelEncoder()
df['gender'] = label_encoder.fit_transform(df['gender'])
df['ever_married'] = label_encoder.fit_transform(df['ever_married'])
df['work_type'] = label_encoder.fit_transform(df['work_type'])
df['Residence_type'] = label_encoder.fit_transform(df['Residence_type'])
df['smoking_status'] = label_encoder.fit_transform(df['smoking_status'])

# Encode the target column (stroke)
df['stroke'] = label_encoder.fit_transform(df['stroke'])

# %%
# Separate features and target variable
X = df.drop(columns=['stroke'])
y = df['stroke']

# One-hot encode the target variable
y = to_categorical(y)

# %%
# Normalize the feature data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the data into training and testing sets (80-20 split)
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Build and train the model

# %%
# Model Parameters
DENSE1_SIZE = 32
DENSE2_SIZE = 16
DENSE3_SIZE = 8
NUM_OF_EPOCHS = 100
BATCH_SIZE = 16

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(DENSE1_SIZE, activation='relu'),
    tf.keras.layers.Dense(DENSE2_SIZE, activation='relu'),
    tf.keras.layers.Dense(DENSE3_SIZE, activation='relu'),
    tf.keras.layers.Dense(y.shape[1], activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 10)                0
#
#  dense (Dense)               (None, 32)                352
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 1,034
# Trainable params: 1,034
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
history = model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=NUM_OF_EPOCHS,
                    verbose=1, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 249/249 [==============================] - 1s 2ms/step - loss: 0.2543 - accuracy: 0.9362 - val_loss: 0.1860 - val_accuracy: 0.9458
# Epoch 2/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1647 - accuracy: 0.9513 - val_loss: 0.1810 - val_accuracy: 0.9458
# Epoch 3/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1587 - accuracy: 0.9513 - val_loss: 0.1805 - val_accuracy: 0.9458
# Epoch 4/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1552 - accuracy: 0.9513 - val_loss: 0.1750 - val_accuracy: 0.9448
# Epoch 5/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1532 - accuracy: 0.9513 - val_loss: 0.1778 - val_accuracy: 0.9458
# Epoch 6/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1516 - accuracy: 0.9516 - val_loss: 0.1776 - val_accuracy: 0.9448
# Epoch 7/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 0.9513 - val_loss: 0.1796 - val_accuracy: 0.9458
# Epoch 8/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1481 - accuracy: 0.9521 - val_loss: 0.1826 - val_accuracy: 0.9458
# Epoch 9/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1475 - accuracy: 0.9516 - val_loss: 0.1826 - val_accuracy: 0.9458
# Epoch 10/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1462 - accuracy: 0.9516 - val_loss: 0.1843 - val_accuracy: 0.9458
# Epoch 11/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1452 - accuracy: 0.9521 - val_loss: 0.1805 - val_accuracy: 0.9448
# Epoch 12/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1444 - accuracy: 0.9523 - val_loss: 0.1871 - val_accuracy: 0.9448
# Epoch 13/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1432 - accuracy: 0.9536 - val_loss: 0.1839 - val_accuracy: 0.9458
# Epoch 14/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1422 - accuracy: 0.9541 - val_loss: 0.1888 - val_accuracy: 0.9458
# Epoch 15/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1405 - accuracy: 0.9531 - val_loss: 0.1826 - val_accuracy: 0.9448
# Epoch 16/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1395 - accuracy: 0.9538 - val_loss: 0.1912 - val_accuracy: 0.9448
# Epoch 17/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1394 - accuracy: 0.9538 - val_loss: 0.1885 - val_accuracy: 0.9458
# Epoch 18/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1387 - accuracy: 0.9536 - val_loss: 0.1891 - val_accuracy: 0.9428
# Epoch 19/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1366 - accuracy: 0.9541 - val_loss: 0.1942 - val_accuracy: 0.9448
# Epoch 20/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.9546 - val_loss: 0.1972 - val_accuracy: 0.9428
# Epoch 21/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1351 - accuracy: 0.9541 - val_loss: 0.1972 - val_accuracy: 0.9418
# Epoch 22/100
# 249/249 [==============================] - 0s 2ms/step - loss: 0.1346 - accuracy: 0.9553 - val_loss: 0.1962 - val_accuracy: 0.9428
# Epoch 23/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1339 - accuracy: 0.9546 - val_loss: 0.1953 - val_accuracy: 0.9418
# Epoch 24/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1323 - accuracy: 0.9568 - val_loss: 0.1999 - val_accuracy: 0.9418
# Epoch 25/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1316 - accuracy: 0.9546 - val_loss: 0.1982 - val_accuracy: 0.9418
# Epoch 26/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1319 - accuracy: 0.9551 - val_loss: 0.1995 - val_accuracy: 0.9388
# Epoch 27/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1324 - accuracy: 0.9538 - val_loss: 0.2003 - val_accuracy: 0.9408
# Epoch 28/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9551 - val_loss: 0.2009 - val_accuracy: 0.9388
# Epoch 29/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1304 - accuracy: 0.9538 - val_loss: 0.2023 - val_accuracy: 0.9388
# Epoch 30/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1296 - accuracy: 0.9538 - val_loss: 0.2030 - val_accuracy: 0.9378
# Epoch 31/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1275 - accuracy: 0.9556 - val_loss: 0.2022 - val_accuracy: 0.9368
# Epoch 32/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1269 - accuracy: 0.9556 - val_loss: 0.2057 - val_accuracy: 0.9388
# Epoch 33/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1266 - accuracy: 0.9556 - val_loss: 0.2087 - val_accuracy: 0.9398
# Epoch 34/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1252 - accuracy: 0.9556 - val_loss: 0.2014 - val_accuracy: 0.9418
# Epoch 35/100
# 249/249 [==============================] - 0s 2ms/step - loss: 0.1252 - accuracy: 0.9551 - val_loss: 0.2111 - val_accuracy: 0.9378
# Epoch 36/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1241 - accuracy: 0.9563 - val_loss: 0.2114 - val_accuracy: 0.9388
# Epoch 37/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9558 - val_loss: 0.2105 - val_accuracy: 0.9378
# Epoch 38/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1238 - accuracy: 0.9568 - val_loss: 0.2137 - val_accuracy: 0.9398
# Epoch 39/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1222 - accuracy: 0.9578 - val_loss: 0.2114 - val_accuracy: 0.9398
# Epoch 40/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1216 - accuracy: 0.9566 - val_loss: 0.2107 - val_accuracy: 0.9388
# Epoch 41/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1207 - accuracy: 0.9588 - val_loss: 0.2152 - val_accuracy: 0.9408
# Epoch 42/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1204 - accuracy: 0.9581 - val_loss: 0.2222 - val_accuracy: 0.9398
# Epoch 43/100
# 249/249 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.9566 - val_loss: 0.2174 - val_accuracy: 0.9358
# Epoch 44/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1189 - accuracy: 0.9561 - val_loss: 0.2220 - val_accuracy: 0.9358
# Epoch 45/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9573 - val_loss: 0.2217 - val_accuracy: 0.9398
# Epoch 46/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1161 - accuracy: 0.9591 - val_loss: 0.2211 - val_accuracy: 0.9418
# Epoch 47/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1172 - accuracy: 0.9578 - val_loss: 0.2201 - val_accuracy: 0.9388
# Epoch 48/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1166 - accuracy: 0.9578 - val_loss: 0.2226 - val_accuracy: 0.9318
# Epoch 49/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1161 - accuracy: 0.9588 - val_loss: 0.2227 - val_accuracy: 0.9378
# Epoch 50/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.9578 - val_loss: 0.2252 - val_accuracy: 0.9408
# Epoch 51/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9591 - val_loss: 0.2265 - val_accuracy: 0.9388
# Epoch 52/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9581 - val_loss: 0.2203 - val_accuracy: 0.9378
# Epoch 53/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1138 - accuracy: 0.9593 - val_loss: 0.2298 - val_accuracy: 0.9398
# Epoch 54/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9571 - val_loss: 0.2317 - val_accuracy: 0.9358
# Epoch 55/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1114 - accuracy: 0.9603 - val_loss: 0.2318 - val_accuracy: 0.9398
# Epoch 56/100
# 249/249 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.9596 - val_loss: 0.2282 - val_accuracy: 0.9348
# Epoch 57/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1122 - accuracy: 0.9578 - val_loss: 0.2267 - val_accuracy: 0.9348
# Epoch 58/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1111 - accuracy: 0.9598 - val_loss: 0.2392 - val_accuracy: 0.9398
# Epoch 59/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1113 - accuracy: 0.9571 - val_loss: 0.2340 - val_accuracy: 0.9308
# Epoch 60/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1100 - accuracy: 0.9616 - val_loss: 0.2321 - val_accuracy: 0.9308
# Epoch 61/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9606 - val_loss: 0.2378 - val_accuracy: 0.9398
# Epoch 62/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1099 - accuracy: 0.9603 - val_loss: 0.2417 - val_accuracy: 0.9368
# Epoch 63/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1072 - accuracy: 0.9596 - val_loss: 0.2416 - val_accuracy: 0.9328
# Epoch 64/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1072 - accuracy: 0.9598 - val_loss: 0.2458 - val_accuracy: 0.9308
# Epoch 65/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1069 - accuracy: 0.9601 - val_loss: 0.2417 - val_accuracy: 0.9328
# Epoch 66/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1068 - accuracy: 0.9626 - val_loss: 0.2462 - val_accuracy: 0.9328
# Epoch 67/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1054 - accuracy: 0.9611 - val_loss: 0.2492 - val_accuracy: 0.9398
# Epoch 68/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.9611 - val_loss: 0.2560 - val_accuracy: 0.9378
# Epoch 69/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1061 - accuracy: 0.9611 - val_loss: 0.2483 - val_accuracy: 0.9348
# Epoch 70/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1049 - accuracy: 0.9616 - val_loss: 0.2595 - val_accuracy: 0.9388
# Epoch 71/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.9601 - val_loss: 0.2491 - val_accuracy: 0.9338
# Epoch 72/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1031 - accuracy: 0.9618 - val_loss: 0.2506 - val_accuracy: 0.9328
# Epoch 73/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1040 - accuracy: 0.9613 - val_loss: 0.2513 - val_accuracy: 0.9388
# Epoch 74/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.9621 - val_loss: 0.2546 - val_accuracy: 0.9348
# Epoch 75/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1011 - accuracy: 0.9601 - val_loss: 0.2684 - val_accuracy: 0.9378
# Epoch 76/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1013 - accuracy: 0.9631 - val_loss: 0.2547 - val_accuracy: 0.9348
# Epoch 77/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1016 - accuracy: 0.9603 - val_loss: 0.2673 - val_accuracy: 0.9378
# Epoch 78/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1006 - accuracy: 0.9613 - val_loss: 0.2661 - val_accuracy: 0.9188
# Epoch 79/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1020 - accuracy: 0.9598 - val_loss: 0.2642 - val_accuracy: 0.9388
# Epoch 80/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9606 - val_loss: 0.2653 - val_accuracy: 0.9318
# Epoch 81/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.1003 - accuracy: 0.9644 - val_loss: 0.2726 - val_accuracy: 0.9388
# Epoch 82/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0989 - accuracy: 0.9618 - val_loss: 0.2683 - val_accuracy: 0.9368
# Epoch 83/100
# 249/249 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9646 - val_loss: 0.2583 - val_accuracy: 0.9288
# Epoch 84/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0980 - accuracy: 0.9629 - val_loss: 0.2682 - val_accuracy: 0.9308
# Epoch 85/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0975 - accuracy: 0.9656 - val_loss: 0.2762 - val_accuracy: 0.9358
# Epoch 86/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0958 - accuracy: 0.9626 - val_loss: 0.2748 - val_accuracy: 0.9348
# Epoch 87/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0977 - accuracy: 0.9616 - val_loss: 0.2770 - val_accuracy: 0.9268
# Epoch 88/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 0.9644 - val_loss: 0.2749 - val_accuracy: 0.9298
# Epoch 89/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9626 - val_loss: 0.2817 - val_accuracy: 0.9318
# Epoch 90/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0948 - accuracy: 0.9634 - val_loss: 0.2779 - val_accuracy: 0.9368
# Epoch 91/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9654 - val_loss: 0.2794 - val_accuracy: 0.9308
# Epoch 92/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0947 - accuracy: 0.9616 - val_loss: 0.2751 - val_accuracy: 0.9298
# Epoch 93/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0937 - accuracy: 0.9646 - val_loss: 0.2807 - val_accuracy: 0.9358
# Epoch 94/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0922 - accuracy: 0.9641 - val_loss: 0.2821 - val_accuracy: 0.9308
# Epoch 95/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0945 - accuracy: 0.9649 - val_loss: 0.2833 - val_accuracy: 0.9348
# Epoch 96/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9654 - val_loss: 0.2845 - val_accuracy: 0.9318
# Epoch 97/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9649 - val_loss: 0.2836 - val_accuracy: 0.9308
# Epoch 98/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0902 - accuracy: 0.9661 - val_loss: 0.2879 - val_accuracy: 0.9338
# Epoch 99/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0916 - accuracy: 0.9654 - val_loss: 0.2992 - val_accuracy: 0.9157
# Epoch 100/100
# 249/249 [==============================] - 0s 1ms/step - loss: 0.0922 - accuracy: 0.9634 - val_loss: 0.2899 - val_accuracy: 0.9318

# %% [markdown]
# ### Evaluate the Model

# %%
# Evaluate the model
train_loss, train_accuracy = model.evaluate(X_train, y_train, verbose=0)
val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Training Accuracy: 96.99%
# Validation Accuracy: 93.18%

# %% [markdown]
# ### Model conversion to header file

# %%
# Save the model
model.save('BrainStrokeModel1.h5')

# %% [markdown]
# ### Model Conversion to TensorFlow Lite

# %%
# Convert the model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Representative dataset for quantization
def representative_dataset():
    for i in range(100):
        yield [X_train.astype(np.float32)]

converter.representative_dataset = representative_dataset
tflite_model = converter.convert()

# Save the TFLite model
with open('BrainStrokeModel1.tflite', 'wb') as f:
    f.write(tflite_model)
print("Model has been converted and saved as 'BrainStrokeModel.tflite'.")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\ssrut\AppData\Local\Temp\tmpam1kp8j5\assets
# INFO:tensorflow:Assets written to: C:\Users\ssrut\AppData\Local\Temp\tmpam1kp8j5\assets
# c:\Users\ssrut\anaconda3\envs\IoT\lib\site-packages\tensorflow\lite\python\convert.py:765: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Model has been converted and saved as 'BrainStrokeModel.tflite'.

# %%
# Function to convert some hex values into an array for C programming
import time, sys

# Function to convert some hex values into an array for C programming
def hex_to_c_array(hex_data, var_name):
    c_str = ""

    # Create header guard
    c_str += '#ifndef ' + var_name.upper() + '_H\n'
    c_str += "#define " + var_name.upper() + '_H\n\n'

    c_str += "/*\n Author: Sruthika Sivakumar \n"
    c_str += " CAUTION: This is an auto generated file.\n DO NOT EDIT OR MAKE ANY CHANGES TO IT.\n"

# Time stamping of this model data in the generated file
    localtime = time.asctime( time.localtime(time.time()) )
    c_str += " This model data was generated on " + localtime+ '\n\n'
    print("This model data was generated on:", localtime)

# Add information about the verisons of tools and packages used in generating this header file
    c_str += " Tools used:\n Python:" + str(sys.version) + "\n Numpy:" + str(np.version.version) + \
          "\n TensorFlow:" + str(sys.version) + "\n Keras: "+ str(tf.keras.__version__) + "\n\n"
    print("Tools used: Python:", sys.version, "\n Numpy:", np.version.version, \
          "\n TensorFlow:", sys.version, "\n Keras: ", tf.keras.__version__, "\n\n")

# Training details of the model
    c_str += ' Model details are:\n'
    c_str += ' NUM_OF_EPOCHS = ' + str(NUM_OF_EPOCHS) + '\n'
    c_str += ' BATCH_SIZE    = ' + str(BATCH_SIZE) + '\n*/\n'
    
# Generate 'C' constants for the no. of nodes in each layer
    c_str += '\nconst int ' + 'DENSE1_SIZE' + ' = ' + str(DENSE1_SIZE) + ';\n'
    c_str +=   'const int ' + 'DENSE2_SIZE' + ' = ' + str(DENSE2_SIZE) + ';\n'      
    
    # Add array length at the top of the file
    c_str += '\nconst unsigned int ' + var_name + '_len = ' + str(len(hex_data)) + ';\n'

    # Declare C variable
    c_str += 'alignas(8) const unsigned char ' + var_name + '[] = {'
    hex_array = []
    for i, val in enumerate(hex_data):
        # Construct string from hex
        hex_str = format(val, '#04x')

        # Add formating so each line stays within 80 characters
        if (i + 1) < len(hex_data):
          hex_str += ','
        if (i + 1) % 12 == 0:
          hex_str += '\n'
        hex_array.append(hex_str)

    # Add closing brace
    c_str += '\n' + format(''.join(hex_array)) + '\n};\n\n'

    # Close out header guard
    c_str += '#endif //' + var_name.upper() + '_H'

    return c_str

# %%
# Write TFLite model to a C source (or header) file
with open("BrainStrokeModel1" + '.h', 'w') as file:
  file.write(hex_to_c_array(tflite_model, "BrainStrokeESP32"))
# Out:
# This model data was generated on: Tue Nov  5 15:25:02 2024
# Tools used: Python: 3.7.16 (default, Jan 17 2023, 16:06:28) [MSC v.1916 64 bit (AMD64)]
#  Numpy: 1.21.5
#  TensorFlow: 3.7.16 (default, Jan 17 2023, 16:06:28) [MSC v.1916 64 bit (AMD64)]
#  Keras:  2.11.0
